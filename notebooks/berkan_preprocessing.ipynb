# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../raw_data/final_datav2.csv", low_memory=False)
data.reset_index(inplace=True)

# %%
data = data.drop_duplicates()
data = data[data.total_funding_usd > 0]
data
# Out:
#       index  Unnamed: 0                Organization Name IPO Status  \
# 0         0           0                           air up    Private
# 1         1           1                   infinite roots    Private
# 2         2           2                        instagrid    Private
# 3         3           3                   isar aerospace    Private
# 4         4           4  sosafe cyber security awareness    Private
# ...     ...         ...                              ...        ...
# 2184   2184        2184                    btc echo gmbh    Private
# 2185   2185        2185                            swipy    Private
# 2186   2186        2186                   regional markt    Private
# 2187   2187        2187                    avant classic    Private
# 2188   2188        2188                          appiris    Private
#
#       Number of Founders Company Type CB Rank (Company) Operating Status  \
# 0                    5.0   For Profit             1,347           Active
# 1                    1.0   For Profit             1,875           Active
# 2                    2.0   For Profit             1,950           Active
# 3                    3.0   For Profit             2,015           Active
# 4                    3.0   For Profit             2,054           Active
# ...                  ...          ...               ...              ...
# 2184                 1.0   For Profit           201,902           Active
# 2185                 2.0   For Profit           213,578           Closed
# 2186                 2.0   For Profit           224,877           Closed
# 2187                 1.0   For Profit           335,005           Closed
# 2188                 3.0   For Profit           466,833           Active
#
#                                         Industry Groups Number of Employees  \
# 0       Commerce and Shopping, Food and Beverage, Other             251-500
# 1     Biotechnology, Food and Beverage, Health Care,...              51-100
# 2                                 Energy, Manufacturing             101-250
# 3     Information Technology, Science and Engineerin...             251-500
# 4     Information Technology, Privacy and Security, ...             251-500
# ...                                                 ...                 ...
# 2184  Blockchain and Cryptocurrency, Content and Pub...               11-50
# 2185  Clothing and Apparel, Commerce and Shopping, C...               11-50
# 2186  Agriculture and Farming, Commerce and Shopping...               11-50
# 2187         Internet Services, Media and Entertainment               11-50
# 2188  Advertising, Consumer Electronics, Hardware, I...               11-50
#
#       ... b_to_a_ratio  c_to_b_ratio  d_to_c_ratio e_to_d_ratio pe_to_e_ratio  \
# 0     ...     0.000000      0.000000           0.0          0.0           0.0
# 1     ...     5.300000      0.000000           0.0          0.0           0.0
# 2     ...     3.411765      3.014828           0.0          0.0           0.0
# 3     ...     5.000000      0.000000           0.0          0.0           0.0
# 4     ...     0.000000      0.000000           0.0          0.0           0.0
# ...   ...          ...           ...           ...          ...           ...
# 2184  ...     0.000000      0.000000           0.0          0.0           0.0
# 2185  ...     0.000000      0.000000           0.0          0.0           0.0
# 2186  ...     0.000000      0.000000           0.0          0.0           0.0
# 2187  ...     0.000000      0.000000           0.0          0.0           0.0
# 2188  ...     0.000000      0.000000           0.0          0.0           0.0
#
#      total_funding_usd has_ico         last_funding_type  last_funding_amount  \
# 0           67922929.0       0  Venture - Series Unknown           46744589.0
# 1           86661948.0       0                  Series B           57481860.0
# 2          137401184.0       0                  Series C           94927569.0
# 3          350641701.0       0                  Series C                  NaN
# 4           73000000.0       0                  Series B           73000000.0
# ...                ...     ...                       ...                  ...
# 2184          145515.0       0                      Seed                  NaN
# 2185           75000.0       0     Non-equity Assistance                  NaN
# 2186          183876.0       0          Convertible Note              72797.0
# 2187           50000.0       0                      Seed              50000.0
# 2188         1371723.0       0  Venture - Series Unknown            1371723.0
#
#      hub_tags
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 2184      NaN
# 2185      NaN
# 2186      NaN
# 2187      NaN
# 2188      NaN
#
# [2178 rows x 77 columns]

# %%
df = data.iloc[:, 13:]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2178 entries, 0 to 2188
# Data columns (total 64 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   city                       2178 non-null   object
#  1   state                      2178 non-null   object
#  2   funding_status             2178 non-null   object
#  3   revenue_range              2178 non-null   object
#  4   no_employees               2178 non-null   object
#  5   no_founders                2178 non-null   float64
#  6   industry_groups            2178 non-null   object
#  7   industry_groups_secondary  2178 non-null   object
#  8   industry_groups_third      2178 non-null   object
#  9   industry_groups_four       2178 non-null   object
#  10  industry_groups_five       2178 non-null   object
#  11  website                    2178 non-null   int64
#  12  phone                      2178 non-null   int64
#  13  email                      2178 non-null   int64
#  14  linkedin                   2178 non-null   int64
#  15  twitter                    2178 non-null   int64
#  16  facebook                   2178 non-null   int64
#  17  articles                   2178 non-null   object
#  18  founded_year               2178 non-null   int64
#  19  last_funding_year          2178 non-null   float64
#  20  exit_year                  305 non-null    float64
#  21  closed_year                56 non-null     float64
#  22  no_investors               2178 non-null   float64
#  23  no_fund_rounds             2178 non-null   float64
#  24  acquired                   2178 non-null   int64
#  25  private_ipo                2178 non-null   int64
#  26  company_type               2178 non-null   int64
#  27  operting_status            2178 non-null   int64
#  28  no_lead_investors          2178 non-null   float64
#  29  no_sub_orgs                2178 non-null   float64
#  30  no_exits                   2178 non-null   float64
#  31  has_preseed                2178 non-null   int64
#  32  has_seed                   2178 non-null   int64
#  33  has_series_a               2178 non-null   int64
#  34  has_series_b               2178 non-null   int64
#  35  has_series_c               2178 non-null   int64
#  36  has_series_d               2178 non-null   int64
#  37  has_series_e               2178 non-null   int64
#  38  has_angel                  2178 non-null   int64
#  39  has_debt_financing         2178 non-null   int64
#  40  has_grant                  2178 non-null   int64
#  41  has_corporate_round        2178 non-null   int64
#  42  has_series_x               2178 non-null   int64
#  43  has_other_funding          2178 non-null   int64
#  44  preseed_fund               364 non-null    float64
#  45  seed_fund                  1044 non-null   float64
#  46  series_a_fund              693 non-null    float64
#  47  series_b_fund              303 non-null    float64
#  48  series_c_fund              118 non-null    float64
#  49  series_d_fund              52 non-null     float64
#  50  series_e_fund              24 non-null     float64
#  51  private_equity_fund        45 non-null     float64
#  52  seed_to_pre_ratio          2178 non-null   float64
#  53  a_to_seed_ratio            2178 non-null   float64
#  54  b_to_a_ratio               2178 non-null   float64
#  55  c_to_b_ratio               2178 non-null   float64
#  56  d_to_c_ratio               2178 non-null   float64
#  57  e_to_d_ratio               2178 non-null   float64
#  58  pe_to_e_ratio              2178 non-null   float64
#  59  total_funding_usd          2178 non-null   float64
#  60  has_ico                    2178 non-null   int64
#  61  last_funding_type          2178 non-null   object
#  62  last_funding_amount        1842 non-null   float64
#  63  hub_tags                   51 non-null     object
# dtypes: float64(26), int64(25), object(13)
# memory usage: 1.1+ MB

# %%
df.funding_status
# Out:
# 0       Early Stage Venture
# 1       Early Stage Venture
# 2        Late Stage Venture
# 3        Late Stage Venture
# 4       Early Stage Venture
#                ...
# 2184                   Seed
# 2185                   Seed
# 2186                   Seed
# 2187                   Seed
# 2188                    M&A
# Name: funding_status, Length: 2178, dtype: object

# %%
successful_public_ipo = list(df[df.private_ipo == 0].index)

# %%
successful_ma = list(df[df.funding_status == "M&A"].index)

# %%
successful_ipo = list(df[df.funding_status == "IPO"].index)

# %%
successful_pe_fu = list(df[df.funding_status == "Private Equity"].index)

# %%
successful_exit = list(df[df.exit_year > 1000].index)

# %%
successful_acquired = list(df[df.acquired > 0].index)

# %%
successful_d = list(df[df.has_series_d > 0].index)

# %%
successful_e = list(df[df.has_series_e > 0].index)

# %%
successful_pe = list(df[df.private_equity_fund > 1000000].index)

# %%
success_pre = list(df[df.seed_to_pre_ratio > 2.3].index)

# %%
success_seed = list(df[df.a_to_seed_ratio > 2.2].index)

# %%
success_a = list(df[df.b_to_a_ratio > 1.7].index)

# %%
success_b = list(df[df.c_to_b_ratio > 1.4].index)

# %%
df[df.c_to_b_ratio > 1.4]
# Out:
#            city               state       funding_status   revenue_range  \
# 2     Stuttgart   Baden-Wurttemberg   Late Stage Venture     $1M to $10M
# 5       Dresden             Sachsen   Late Stage Venture     $1M to $10M
# 7        Munich              Bayern                  IPO   Less than $1M
# 88       Berlin              Berlin   Late Stage Venture  $100M to $500M
# 92       Berlin              Berlin   Late Stage Venture  $100M to $500M
# ...         ...                 ...                  ...             ...
# 2030     Munich              Bayern   Late Stage Venture   Less than $1M
# 2032     Munich              Bayern   Late Stage Venture    $10M to $50M
# 2034     Berlin              Berlin   Late Stage Venture    $10M to $50M
# 2041     Berlin              Berlin   Late Stage Venture    $10M to $50M
# 2098     Berlin              Berlin  Early Stage Venture     $1M to $10M
#
#      no_employees  no_founders               industry_groups  \
# 2         101-250          2.0  Energy and Natural Resources
# 5         101-250          8.0       Technology and Software
# 7         101-250          4.0  Healthcare and Biotechnology
# 88        251-500          2.0        Education and Training
# 92        101-250          2.0       Technology and Software
# ...           ...          ...                           ...
# 2030      101-250          2.0  Healthcare and Biotechnology
# 2032      101-250          5.0       Technology and Software
# 2034      101-250          2.0         Retail and E-commerce
# 2041      101-250          2.0       Technology and Software
# 2098      101-250          4.0       Technology and Software
#
#                      industry_groups_secondary    industry_groups_third  \
# 2                   Manufacturing and Industry                       -1
# 5                     Hardware and Electronics  Technology and Software
# 7                 Healthcare and Biotechnology  Science and Engineering
# 88                     Technology and Software                       -1
# 92    Telecommunications and Internet Services                    Other
# ...                                        ...                      ...
# 2030                   Technology and Software                       -1
# 2032                   Technology and Software  Technology and Software
# 2034              Transportation and Logistics                       -1
# 2041                     Retail and E-commerce                       -1
# 2098                         Business Services  Technology and Software
#
#          industry_groups_four  ... b_to_a_ratio  c_to_b_ratio  d_to_c_ratio  \
# 2                          -1  ...     3.411765      3.014828      0.000000
# 5           Business Services  ...     5.000000      2.800000      0.000000
# 7                          -1  ...     1.686275      2.162791      1.688172
# 88                         -1  ...     3.809524      2.500000      0.000000
# 92    Technology and Software  ...     8.333333      4.000000      0.000000
# ...                       ...  ...          ...           ...           ...
# 2030                       -1  ...     0.000000      1.533333      0.000000
# 2032  Science and Engineering  ...     0.000000      5.652174      0.000000
# 2034                       -1  ...     2.461538      2.500000      0.000000
# 2041                       -1  ...     2.666667      2.225000      0.000000
# 2098                       -1  ...     2.031250      1.423077      0.000000
#
#       e_to_d_ratio  pe_to_e_ratio  total_funding_usd  has_ico  \
# 2              0.0            0.0        137401184.0        0
# 5              0.0            0.0        122184409.0        0
# 7              0.0            0.0        522100000.0        0
# 88             0.0            0.0        333490482.0        0
# 92             0.0            0.0        308000000.0        1
# ...            ...            ...                ...      ...
# 2030           0.0            0.0         65772234.0        0
# 2032           0.0            0.0        130614117.0        0
# 2034           0.0            0.0         65798538.0        0
# 2041           0.0            0.0         33970218.0        0
# 2098           0.0            0.0         92215781.0        0
#
#              last_funding_type  last_funding_amount        hub_tags
# 2                     Series C           94927569.0             NaN
# 5                     Series C           84000000.0             NaN
# 7                Post-IPO Debt          175000000.0  Exited Unicorn
# 88                    Series C          200000000.0             NaN
# 92       Initial Coin Offering           50000000.0             NaN
# ...                        ...                  ...             ...
# 2030                  Series C           24533176.0             NaN
# 2032                  Series C           78980207.0             NaN
# 2034  Venture - Series Unknown                  NaN             NaN
# 2041                  Series C           20989749.0             NaN
# 2098               Undisclosed                  NaN             NaN
#
# [67 rows x 64 columns]

# %%
success_unicorn = list(df[df["hub_tags"] == "Unicorn"].index)
success_emerging_unicorn = list(df[df["hub_tags"] == "Emerging Unicorn"].index)

# %%
success_target = successful_public_ipo + \
                successful_ma + \
                successful_ipo + \
                successful_pe_fu + \
                successful_exit + \
                successful_acquired + \
                success_unicorn + \
                success_emerging_unicorn
secondary_success = successful_d + \
                successful_e + \
                successful_pe + \
                success_pre + \
                success_seed + \
                success_a + \
                success_b
len(set(success_target))
# Out:
# 433

# %%
len(set(secondary_success))
# Out:
# 518

# %%
len(set(success_target + secondary_success))
# Out:
# 801

# %%
closed_companies = df[df.closed_year > 0]
closed_companies = closed_companies[closed_companies.acquired == 0]
failed_seed = list(closed_companies[closed_companies.funding_status == "Seed"].index)

# %%
failed_early = list(closed_companies[closed_companies.funding_status == "Early Stage Venture"].index)

# %%
fail_pre = df[df.seed_to_pre_ratio < 2.3]
fail_pre = list(fail_pre[fail_pre.seed_to_pre_ratio > 0].index)

# %%
fail_seed = df[df.a_to_seed_ratio < 2.2]
fail_seed = list(fail_seed[fail_seed.a_to_seed_ratio > 0].index)

# %%
fail_a = df[df.b_to_a_ratio < 1.7] 
fail_a = list(fail_a[fail_a.b_to_a_ratio > 0].index)

# %%
fail_b = df[df.c_to_b_ratio < 1.4]   
fail_b = list(fail_b[fail_b.c_to_b_ratio > 0].index)

# %%
failure_target = failed_seed + failed_early
failure_secondary = fail_pre + fail_seed + fail_a + fail_b

# %%
len(set(failure_target))
# Out:
# 23

# %%
both_ways = []
for i in failure_secondary:
    if i in secondary_success:
        both_ways.append(i)
len(both_ways)
# Out:
# 84

# %%
both_way = []
for i in failure_target:
    if i in success_target:
        both_way.append(i)
len(both_way)
# Out:
# 0

# %%
df["y"] = 2

# %%
df.loc[list(set(success_target)), ["y"]] = 1

# %%
df.loc[list(set(failure_target)), ["y"]] = 0

# %%
df[df["y"] > 1]
# Out:
#            city                 state       funding_status   revenue_range  \
# 0        Munich                Bayern  Early Stage Venture  $100M to $500M
# 1       Hamburg               Hamburg  Early Stage Venture     $1M to $10M
# 2     Stuttgart     Baden-Wurttemberg   Late Stage Venture     $1M to $10M
# 3        Munich                Bayern   Late Stage Venture    $10M to $50M
# 4          Köln   Nordrhein-Westfalen  Early Stage Venture   $50M to $100M
# ...         ...                   ...                  ...             ...
# 2180   Mannheim     Baden-Wurttemberg                 Seed     $1M to $10M
# 2181   Dreieich                Hessen                 Seed   Less than $1M
# 2184     Berlin                Berlin                 Seed     $1M to $10M
# 2185   Butzbach                Hessen                 Seed     $1M to $10M
# 2187     Berlin                Berlin                 Seed     $1M to $10M
#
#      no_employees  no_founders                           industry_groups  \
# 0         251-500          5.0                     Retail and E-commerce
# 1          51-100          1.0              Healthcare and Biotechnology
# 2         101-250          2.0              Energy and Natural Resources
# 3         251-500          3.0                   Technology and Software
# 4         251-500          3.0                   Technology and Software
# ...           ...          ...                                       ...
# 2180        11-50          1.0                   Technology and Software
# 2181        11-50          1.0                         Business Services
# 2184        11-50          1.0                   Technology and Software
# 2185        11-50          2.0                         Consumer Products
# 2187        11-50          1.0  Telecommunications and Internet Services
#
#        industry_groups_secondary         industry_groups_third  \
# 0              Consumer Products                         Other
# 1              Consumer Products  Healthcare and Biotechnology
# 2     Manufacturing and Industry                            -1
# 3        Science and Engineering  Transportation and Logistics
# 4        Technology and Software       Technology and Software
# ...                          ...                           ...
# 2180           Business Services  Transportation and Logistics
# 2181                          -1                            -1
# 2184     Media and Entertainment       Technology and Software
# 2185       Retail and E-commerce       Community and Lifestyle
# 2187     Media and Entertainment                            -1
#
#          industry_groups_four  ... c_to_b_ratio  d_to_c_ratio  e_to_d_ratio  \
# 0                          -1  ...     0.000000           0.0           0.0
# 1     Science and Engineering  ...     0.000000           0.0           0.0
# 2                          -1  ...     3.014828           0.0           0.0
# 3                          -1  ...     0.000000           0.0           0.0
# 4                          -1  ...     0.000000           0.0           0.0
# ...                       ...  ...          ...           ...           ...
# 2180                       -1  ...     0.000000           0.0           0.0
# 2181                       -1  ...     0.000000           0.0           0.0
# 2184        Business Services  ...     0.000000           0.0           0.0
# 2185        Business Services  ...     0.000000           0.0           0.0
# 2187                       -1  ...     0.000000           0.0           0.0
#
#       pe_to_e_ratio  total_funding_usd  has_ico         last_funding_type  \
# 0               0.0         67922929.0        0  Venture - Series Unknown
# 1               0.0         86661948.0        0                  Series B
# 2               0.0        137401184.0        0                  Series C
# 3               0.0        350641701.0        0                  Series C
# 4               0.0         73000000.0        0                  Series B
# ...             ...                ...      ...                       ...
# 2180            0.0            27284.0        0                      Seed
# 2181            0.0            81868.0        0                     Grant
# 2184            0.0           145515.0        0                      Seed
# 2185            0.0            75000.0        0     Non-equity Assistance
# 2187            0.0            50000.0        0                      Seed
#
#      last_funding_amount  hub_tags  y
# 0             46744589.0       NaN  2
# 1             57481860.0       NaN  2
# 2             94927569.0       NaN  2
# 3                    NaN       NaN  2
# 4             73000000.0       NaN  2
# ...                  ...       ... ..
# 2180             27284.0       NaN  2
# 2181             81868.0       NaN  2
# 2184                 NaN       NaN  2
# 2185                 NaN       NaN  2
# 2187             50000.0       NaN  2
#
# [1722 rows x 65 columns]

# %%
df[df["y"] == 1]
# Out:
#             city                 state  funding_status  revenue_range  \
# 6       Gilching                Bayern             M&A  $50M to $100M
# 7         Munich                Bayern             IPO  Less than $1M
# 20        Berlin                Berlin             IPO   $10M to $50M
# 34     Wiesbaden                Hessen  Private Equity    $1M to $10M
# 35        Munich                Bayern             M&A    $1M to $10M
# ...          ...                   ...             ...            ...
# 2156  Düsseldorf   Nordrhein-Westfalen             M&A   $10M to $50M
# 2170      Berlin                Berlin             M&A    $1M to $10M
# 2175      Berlin                Berlin             M&A    $1M to $10M
# 2182      Berlin                Berlin             M&A  Less than $1M
# 2188      Berlin                Berlin             M&A  Less than $1M
#
#      no_employees  no_founders               industry_groups  \
# 6        501-1000          3.0       Technology and Software
# 7         101-250          4.0  Healthcare and Biotechnology
# 20        101-250          3.0  Energy and Natural Resources
# 34          11-50          1.0    Manufacturing and Industry
# 35         51-100          3.0         Retail and E-commerce
# ...           ...          ...                           ...
# 2156      101-250          2.0         Retail and E-commerce
# 2170        11-50          2.0       Technology and Software
# 2175        11-50          3.0      Hardware and Electronics
# 2182        11-50          2.0       Technology and Software
# 2188        11-50          3.0             Business Services
#
#                      industry_groups_secondary  \
# 6                      Technology and Software
# 7                 Healthcare and Biotechnology
# 20                Energy and Natural Resources
# 34                  Manufacturing and Industry
# 35                                       Other
# ...                                        ...
# 2156                      Finance and Payments
# 2170  Telecommunications and Internet Services
# 2175                  Hardware and Electronics
# 2182                         Business Services
# 2188                  Hardware and Electronics
#
#                          industry_groups_third  \
# 6                     Hardware and Electronics
# 7                      Science and Engineering
# 20                     Technology and Software
# 34                                          -1
# 35                Transportation and Logistics
# ...                                        ...
# 2156  Telecommunications and Internet Services
# 2170                   Media and Entertainment
# 2175                                        -1
# 2182                   Media and Entertainment
# 2188                  Hardware and Electronics
#
#                           industry_groups_four  ... c_to_b_ratio  \
# 6                   Manufacturing and Industry  ...     0.000000
# 7                                           -1  ...     2.162791
# 20                Energy and Natural Resources  ...     0.000000
# 34                                          -1  ...     0.000000
# 35                                          -1  ...     0.000000
# ...                                        ...  ...          ...
# 2156                         Business Services  ...     0.000000
# 2170                                        -1  ...     0.000000
# 2175                                        -1  ...     0.000000
# 2182  Telecommunications and Internet Services  ...     0.000000
# 2188  Telecommunications and Internet Services  ...     0.000000
#
#       d_to_c_ratio  e_to_d_ratio  pe_to_e_ratio  total_funding_usd  has_ico  \
# 6         0.000000           0.0            0.0        270050589.0        0
# 7         1.688172           0.0            0.0        522100000.0        0
# 20        0.000000           0.0            0.0        132246582.0        0
# 34        0.000000           0.0            0.0        227276085.0        0
# 35        0.000000           0.0            0.0        190190966.0        0
# ...            ...           ...            ...                ...      ...
# 2156      0.000000           0.0            0.0         50856135.0        0
# 2170      0.000000           0.0            0.0          1441367.0        0
# 2175      0.000000           0.0            0.0          6745373.0        0
# 2182      0.000000           0.0            0.0           129685.0        0
# 2188      0.000000           0.0            0.0          1371723.0        0
#
#              last_funding_type last_funding_amount        hub_tags  y
# 6     Venture - Series Unknown          30000000.0         Unicorn  1
# 7                Post-IPO Debt         175000000.0  Exited Unicorn  1
# 20               Post-IPO Debt          26671161.0             NaN  1
# 34              Private Equity         227276084.0             NaN  1
# 35              Debt Financing         154190965.0             NaN  1
# ...                        ...                 ...             ... ..
# 2156          Secondary Market          50856134.0             NaN  1
# 2170     Non-equity Assistance            537004.0             NaN  1
# 2175                  Series A                 NaN             NaN  1
# 2182                     Grant            129684.0             NaN  1
# 2188  Venture - Series Unknown           1371723.0             NaN  1
#
# [433 rows x 65 columns]

# %%
df[df["y"] == 0]
# Out:
#                  city                 state       funding_status  \
# 166            Berlin                Berlin                 Seed
# 204        Düsseldorf   Nordrhein-Westfalen                 Seed
# 205            Berlin                Berlin                 Seed
# 443            Berlin                Berlin                 Seed
# 467            Berlin                Berlin                 Seed
# 553            Berlin                Berlin                 Seed
# 634           Hamburg               Hamburg                 Seed
# 689            Berlin                Berlin                 Seed
# 921            Berlin                Berlin                 Seed
# 925            Berlin                Berlin                 Seed
# 1010           Berlin                Berlin                 Seed
# 1014          Hamburg               Hamburg                 Seed
# 1190          Hamburg               Hamburg  Early Stage Venture
# 1257           Berlin                Berlin  Early Stage Venture
# 1321           Berlin                Berlin                 Seed
# 1727          München                Bayern                 Seed
# 1730           Berlin                Berlin                 Seed
# 2095           Berlin                Berlin  Early Stage Venture
# 2148  Prenzlauer Berg                Berlin                 Seed
# 2163             Bonn   Nordrhein-Westfalen                 Seed
# 2164        Kreuzberg                Berlin  Early Stage Venture
# 2183           Berlin                Berlin  Early Stage Venture
# 2186           Munich                Bayern                 Seed
#
#       revenue_range no_employees  no_founders  \
# 166   Less than $1M        11-50          2.0
# 204     $1M to $10M        11-50          1.0
# 205     $1M to $10M        11-50          4.0
# 443     $1M to $10M    1001-5000          2.0
# 467     $1M to $10M        11-50          1.0
# 553    $10M to $50M        11-50          3.0
# 634     $1M to $10M        11-50          2.0
# 689   Less than $1M        11-50          3.0
# 921   Less than $1M        11-50          1.0
# 925     $1M to $10M        11-50          3.0
# 1010    $1M to $10M        11-50          3.0
# 1014  Less than $1M        11-50          3.0
# 1190    $1M to $10M        11-50          3.0
# 1257    $1M to $10M        11-50          2.0
# 1321  Less than $1M        11-50          3.0
# 1727    $1M to $10M        11-50          3.0
# 1730    $1M to $10M        11-50          3.0
# 2095    $1M to $10M        11-50          5.0
# 2148    $1M to $10M        11-50          3.0
# 2163    $1M to $10M        11-50          1.0
# 2164    $1M to $10M        11-50          1.0
# 2183    $1M to $10M        11-50          2.0
# 2186    $1M to $10M        11-50          2.0
#
#                                industry_groups  \
# 166                    Technology and Software
# 204                    Technology and Software
# 205                          Business Services
# 443                      Retail and E-commerce
# 467                   Hardware and Electronics
# 553                    Technology and Software
# 634                          Consumer Products
# 689                    Technology and Software
# 921                    Technology and Software
# 925                    Technology and Software
# 1010  Telecommunications and Internet Services
# 1014  Telecommunications and Internet Services
# 1190                         Business Services
# 1257                         Consumer Products
# 1321                   Technology and Software
# 1727                  Hardware and Electronics
# 1730                  Hardware and Electronics
# 2095                      Finance and Payments
# 2148                   Technology and Software
# 2163                         Consumer Products
# 2164                     Retail and E-commerce
# 2183                   Technology and Software
# 2186                Manufacturing and Industry
#
#                      industry_groups_secondary  \
# 166   Telecommunications and Internet Services
# 204                    Technology and Software
# 205                    Technology and Software
# 443                          Consumer Products
# 467   Telecommunications and Internet Services
# 553   Telecommunications and Internet Services
# 634                      Retail and E-commerce
# 689   Telecommunications and Internet Services
# 921                       Finance and Payments
# 925   Telecommunications and Internet Services
# 1010                   Technology and Software
# 1014                   Media and Entertainment
# 1190                Manufacturing and Industry
# 1257              Healthcare and Biotechnology
# 1321                     Retail and E-commerce
# 1727                    Education and Training
# 1730                   Media and Entertainment
# 2095                      Finance and Payments
# 2148                   Technology and Software
# 2163                     Retail and E-commerce
# 2164                         Consumer Products
# 2183            Government and Public Services
# 2186                     Retail and E-commerce
#
#                          industry_groups_third  \
# 166                    Technology and Software
# 204   Telecommunications and Internet Services
# 205                    Technology and Software
# 443   Telecommunications and Internet Services
# 467                    Science and Engineering
# 553                    Media and Entertainment
# 634                          Business Services
# 689                                      Other
# 921                                      Other
# 925                    Media and Entertainment
# 1010                     Retail and E-commerce
# 1014                                        -1
# 1190                   Science and Engineering
# 1257                                        -1
# 1321  Telecommunications and Internet Services
# 1727                  Hardware and Electronics
# 1730                  Hardware and Electronics
# 2095                                        -1
# 2148                                        -1
# 2163                   Community and Lifestyle
# 2164  Telecommunications and Internet Services
# 2183                   Technology and Software
# 2186  Telecommunications and Internet Services
#
#                           industry_groups_four  ... c_to_b_ratio  \
# 166                    Community and Lifestyle  ...          0.0
# 204                    Media and Entertainment  ...          0.0
# 205                     Education and Training  ...          0.0
# 443               Transportation and Logistics  ...          0.0
# 467                    Technology and Software  ...          0.0
# 553   Telecommunications and Internet Services  ...          0.0
# 634                       Finance and Payments  ...          0.0
# 689                    Technology and Software  ...          0.0
# 921                       Finance and Payments  ...          0.0
# 925   Telecommunications and Internet Services  ...          0.0
# 1010                   Technology and Software  ...          0.0
# 1014                                        -1  ...          0.0
# 1190              Energy and Natural Resources  ...          0.0
# 1257                                        -1  ...          0.0
# 1321                   Technology and Software  ...          0.0
# 1727                   Technology and Software  ...          0.0
# 1730                   Media and Entertainment  ...          0.0
# 2095                                        -1  ...          0.0
# 2148                                        -1  ...          0.0
# 2163                         Business Services  ...          0.0
# 2164              Transportation and Logistics  ...          0.0
# 2183                   Technology and Software  ...          0.0
# 2186                                     Other  ...          0.0
#
#       d_to_c_ratio  e_to_d_ratio  pe_to_e_ratio  total_funding_usd  has_ico  \
# 166            0.0           0.0            0.0          1012483.0        0
# 204            0.0           0.0            0.0           192000.0        0
# 205            0.0           0.0            0.0           215406.0        0
# 443            0.0           0.0            0.0          6777697.0        0
# 467            0.0           0.0            0.0          3900000.0        0
# 553            0.0           0.0            0.0         12200000.0        0
# 634            0.0           0.0            0.0          3166420.0        0
# 689            0.0           0.0            0.0            55092.0        0
# 921            0.0           0.0            0.0           100000.0        0
# 925            0.0           0.0            0.0           807961.0        0
# 1010           0.0           0.0            0.0           250000.0        0
# 1014           0.0           0.0            0.0         34474532.0        0
# 1190           0.0           0.0            0.0         11209814.0        0
# 1257           0.0           0.0            0.0          5387459.0        0
# 1321           0.0           0.0            0.0          1781225.0        0
# 1727           0.0           0.0            0.0          1244693.0        0
# 1730           0.0           0.0            0.0          3473295.0        0
# 2095           0.0           0.0            0.0          5163389.0        0
# 2148           0.0           0.0            0.0          4182824.0        0
# 2163           0.0           0.0            0.0          1703939.0        0
# 2164           0.0           0.0            0.0          3644307.0        0
# 2183           0.0           0.0            0.0          5015405.0        0
# 2186           0.0           0.0            0.0           183876.0        0
#
#              last_funding_type last_funding_amount  hub_tags  y
# 166                   Pre-Seed            543055.0       NaN  0
# 204                      Grant             27000.0       NaN  0
# 205                      Grant            154730.0       NaN  0
# 443                      Angel           5694229.0       NaN  0
# 467                       Seed           3900000.0       NaN  0
# 553                       Seed          11000000.0       NaN  0
# 634                       Seed           2102388.0       NaN  0
# 689                   Pre-Seed             55092.0       NaN  0
# 921                   Pre-Seed             80000.0       NaN  0
# 925                   Pre-Seed            588928.0       NaN  0
# 1010                     Angel            250000.0       NaN  0
# 1014           Corporate Round          34474532.0       NaN  0
# 1190                  Series A           9273753.0       NaN  0
# 1257                  Series A           2802376.0       NaN  0
# 1321                      Seed           1736565.0       NaN  0
# 1727      Product Crowdfunding            659661.0       NaN  0
# 1730  Venture - Series Unknown                 NaN       NaN  0
# 2095                  Series A           3163389.0       NaN  0
# 2148                      Seed           4182823.0       NaN  0
# 2163       Equity Crowdfunding           1703939.0       NaN  0
# 2164                  Series A           3644306.0       NaN  0
# 2183  Venture - Series Unknown                 NaN       NaN  0
# 2186          Convertible Note             72797.0       NaN  0
#
# [23 rows x 65 columns]

# %%
failure_secondary = [x for x in failure_secondary if x not in both_ways]
failure_secondary = [x for x in failure_secondary if x not in success_target]
failure_secondary = [x for x in failure_secondary if x not in secondary_success]
failure_secondary = [x for x in failure_secondary if x not in failure_target]

# %%
secondary_success = [x for x in secondary_success if x not in both_ways]
secondary_success = [x for x in secondary_success if x not in failure_target]
secondary_success = [x for x in secondary_success if x not in failure_secondary]
secondary_success = [x for x in secondary_success if x not in success_target]

# %%
len(set(failure_secondary))
# Out:
# 77

# %%
len(set(secondary_success))
# Out:
# 322

# %%
df.loc[list(set(secondary_success)), ["y"]] = 1

# %%
df.loc[list(set(failure_secondary)), ["y"]] = 0

# %%
certain_list = list(df[df["y"] < 2].index)

# %%
undecided_list = [x for x in both_ways if x not in certain_list]

# %%
df[df["y"] < 2]
# Out:
#            city               state       funding_status  revenue_range  \
# 1       Hamburg             Hamburg  Early Stage Venture    $1M to $10M
# 2     Stuttgart   Baden-Wurttemberg   Late Stage Venture    $1M to $10M
# 3        Munich              Bayern   Late Stage Venture   $10M to $50M
# 5       Dresden             Sachsen   Late Stage Venture    $1M to $10M
# 6      Gilching              Bayern                  M&A  $50M to $100M
# ...         ...                 ...                  ...            ...
# 2175     Berlin              Berlin                  M&A    $1M to $10M
# 2182     Berlin              Berlin                  M&A  Less than $1M
# 2183     Berlin              Berlin  Early Stage Venture    $1M to $10M
# 2186     Munich              Bayern                 Seed    $1M to $10M
# 2188     Berlin              Berlin                  M&A  Less than $1M
#
#      no_employees  no_founders               industry_groups  \
# 1          51-100          1.0  Healthcare and Biotechnology
# 2         101-250          2.0  Energy and Natural Resources
# 3         251-500          3.0       Technology and Software
# 5         101-250          8.0       Technology and Software
# 6        501-1000          3.0       Technology and Software
# ...           ...          ...                           ...
# 2175        11-50          3.0      Hardware and Electronics
# 2182        11-50          2.0       Technology and Software
# 2183        11-50          2.0       Technology and Software
# 2186        11-50          2.0    Manufacturing and Industry
# 2188        11-50          3.0             Business Services
#
#            industry_groups_secondary  \
# 1                  Consumer Products
# 2         Manufacturing and Industry
# 3            Science and Engineering
# 5           Hardware and Electronics
# 6            Technology and Software
# ...                              ...
# 2175        Hardware and Electronics
# 2182               Business Services
# 2183  Government and Public Services
# 2186           Retail and E-commerce
# 2188        Hardware and Electronics
#
#                          industry_groups_third  \
# 1                 Healthcare and Biotechnology
# 2                                           -1
# 3                 Transportation and Logistics
# 5                      Technology and Software
# 6                     Hardware and Electronics
# ...                                        ...
# 2175                                        -1
# 2182                   Media and Entertainment
# 2183                   Technology and Software
# 2186  Telecommunications and Internet Services
# 2188                  Hardware and Electronics
#
#                           industry_groups_four  ... c_to_b_ratio  \
# 1                      Science and Engineering  ...     0.000000
# 2                                           -1  ...     3.014828
# 3                                           -1  ...     0.000000
# 5                            Business Services  ...     2.800000
# 6                   Manufacturing and Industry  ...     0.000000
# ...                                        ...  ...          ...
# 2175                                        -1  ...     0.000000
# 2182  Telecommunications and Internet Services  ...     0.000000
# 2183                   Technology and Software  ...     0.000000
# 2186                                     Other  ...     0.000000
# 2188  Telecommunications and Internet Services  ...     0.000000
#
#       d_to_c_ratio  e_to_d_ratio  pe_to_e_ratio  total_funding_usd  has_ico  \
# 1              0.0           0.0            0.0         86661948.0        0
# 2              0.0           0.0            0.0        137401184.0        0
# 3              0.0           0.0            0.0        350641701.0        0
# 5              0.0           0.0            0.0        122184409.0        0
# 6              0.0           0.0            0.0        270050589.0        0
# ...            ...           ...            ...                ...      ...
# 2175           0.0           0.0            0.0          6745373.0        0
# 2182           0.0           0.0            0.0           129685.0        0
# 2183           0.0           0.0            0.0          5015405.0        0
# 2186           0.0           0.0            0.0           183876.0        0
# 2188           0.0           0.0            0.0          1371723.0        0
#
#              last_funding_type last_funding_amount  hub_tags  y
# 1                     Series B          57481860.0       NaN  1
# 2                     Series C          94927569.0       NaN  1
# 3                     Series C                 NaN       NaN  1
# 5                     Series C          84000000.0       NaN  1
# 6     Venture - Series Unknown          30000000.0   Unicorn  1
# ...                        ...                 ...       ... ..
# 2175                  Series A                 NaN       NaN  1
# 2182                     Grant            129684.0       NaN  1
# 2183  Venture - Series Unknown                 NaN       NaN  0
# 2186          Convertible Note             72797.0       NaN  0
# 2188  Venture - Series Unknown           1371723.0       NaN  1
#
# [855 rows x 65 columns]

# %%
df.columns
# Out:
# Index(['city', 'state', 'funding_status', 'revenue_range', 'no_employees',
#        'no_founders', 'industry_groups', 'industry_groups_secondary',
#        'industry_groups_third', 'industry_groups_four', 'industry_groups_five',
#        'website', 'phone', 'email', 'linkedin', 'twitter', 'facebook',
#        'articles', 'founded_year', 'last_funding_year', 'exit_year',
#        'closed_year', 'no_investors', 'no_fund_rounds', 'acquired',
#        'private_ipo', 'company_type', 'operting_status', 'no_lead_investors',
#        'no_sub_orgs', 'no_exits', 'has_preseed', 'has_seed', 'has_series_a',
#        'has_series_b', 'has_series_c', 'has_series_d', 'has_series_e',
#        'has_angel', 'has_debt_financing', 'has_grant', 'has_corporate_round',
#        'has_series_x', 'has_other_funding', 'preseed_fund', 'seed_fund',
#        'series_a_fund', 'series_b_fund', 'series_c_fund', 'series_d_fund',
#        'series_e_fund', 'private_equity_fund', 'seed_to_pre_ratio',
#        'a_to_seed_ratio', 'b_to_a_ratio', 'c_to_b_ratio', 'd_to_c_ratio',
#        'e_to_d_ratio', 'pe_to_e_ratio', 'total_funding_usd', 'has_ico',
#        'last_funding_type', 'last_funding_amount', 'hub_tags', 'y'],
#       dtype='object')

# %%
y = [
    "exit_year", "closed_year", "acquired", "funding_status", "has_series_d", "has_series_e"
]

# %% [markdown]
# Pre-Seed: $50,000 - $500,000
# Seed: $500,000 - $2 Millionen
# Series A: $2 Millionen - $15 Millionen
# Series B: $15 Millionen - $50 Millionen
# Series C: $50 Millionen - $100 Millionen
# Series D: $100 Millionen - $200 Millionen
# Series E und darüber hinaus: $200 Millionen und mehr

# %%
export_df = df.loc[:, ['state', 'funding_status', 'revenue_range', 'no_employees',
       'no_founders', 'industry_groups', 'website', 'phone', 'email',
       'linkedin', 'twitter', 'facebook', 'founded_year','no_investors', 'no_fund_rounds', 'private_ipo', 'company_type',
       'operting_status', 'no_lead_investors', 'no_sub_orgs',
       'has_preseed', 'has_seed', 'has_series_a', 'has_series_b',
       'has_series_c', 'has_series_d', 'has_series_e', 'has_angel',
       'has_debt_financing', 'has_grant', 'has_corporate_round',
       'has_series_x', 'has_ico', 'total_funding_usd', 'y']]

# %%
export_df.to_csv("../raw_data/X_y_data1.csv")
